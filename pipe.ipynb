# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO

# %%
input_folder = r'D:\ai\subhi\undistorted gear images'  # Raw images for model 1
model1_path = r'D:\ai\subhi\dante.pt'          # Teeth detection model
model2_path = r'D:\ai\subhi\best2.pt'                   # Circle detection model

output_root = r'D:\ai\subhi\predictions'  # Use Windows path here

model1_output_folder = os.path.join(output_root, 'model1_non_defective')
model2_annotated_folder = os.path.join(output_root, 'model2_annotated')
model2_circle_folder = os.path.join(model2_annotated_folder, 'circles')
log_path = os.path.join(output_root, "diameter_log.txt")

os.makedirs(model1_output_folder, exist_ok=True)
os.makedirs(model2_annotated_folder, exist_ok=True)
os.makedirs(model2_circle_folder, exist_ok=True)

PIXEL_TO_MM = 0.1972
EXPECTED_TEETH = 18
EXPECTED_DIAMETER_MM = 40.0
ERROR_CORRECTION_MM = 1.35
TOLERANCE_MM = 1.35

assert os.path.exists(model1_path), f"Model 1 weights missing: {model1_path}"
assert os.path.exists(model2_path), f"Model 2 weights missing: {model2_path}"

model1 = YOLO(model1_path)
model2 = YOLO(model2_path)

def label_teeth_defect(detected_teeth_count, expected_teeth):
    return detected_teeth_count == expected_teeth

def is_circle(cnt, threshold=0.7):
    perimeter = cv2.arcLength(cnt, True)
    area = cv2.contourArea(cnt)
    if perimeter == 0:
        return False
    circularity = 4 * np.pi * (area / (perimeter ** 2))
    return circularity > threshold

# %%
# --- Model 1: Teeth Detection ---
input_images = [f for f in os.listdir(input_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

if not input_images:
    print(f"⚠️ No images found in input folder: {input_folder}")
else:
    print(f"ℹ️ Found {len(input_images)} images in input folder for Model 1.")

diameter_log = []
saved_non_defective_images = 0

print("=== Running Model 1: Teeth Detection ===")
for fname in input_images:
    img_path = os.path.join(input_folder, fname)
    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Cannot read image {fname}, skipping.")
        continue

    results = model1(img_path)[0]

    detected_teeth = 0
    if results.boxes and results.boxes.xyxy is not None:
        detected_teeth = len(results.boxes.xyxy.cpu().numpy())

    is_defective = not label_teeth_defect(detected_teeth, EXPECTED_TEETH)

    if is_defective:
        print(f"❌ {fname}: Defective teeth count ({detected_teeth}) != expected ({EXPECTED_TEETH})")
        # Skip saving defective
        continue
    else:
        print(f"✅ {fname}: Teeth OK ({detected_teeth}) - saved for Model 2")
        save_path = os.path.join(model1_output_folder, fname)
        cv2.imwrite(save_path, img)
        saved_non_defective_images += 1

if saved_non_defective_images == 0:
    print(f"⚠️ No non-defective images found after Model 1 detection.")
else:
    print(f"✅ Saved {saved_non_defective_images} non-defective images to: {model1_output_folder}")
# Out:
# ℹ️ Found 61 images in input folder for Model 1.
# === Running Model 1: Teeth Detection ===
#
# image 1/1 D:\ai\subhi\undistorted gear images\1.jpg: 384x640 1 spur gear, 20 teeths, 91.8ms
# Speed: 11.4ms preprocess, 91.8ms inference, 342.4ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 1.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\10.jpg: 384x640 1 spur gear, 20 teeths, 8.8ms
# Speed: 5.3ms preprocess, 8.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 10.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\11.jpg: 384x640 1 spur gear, 20 teeths, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 11.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\12.jpg: 384x640 1 spur gear, 20 teeths, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 12.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\13.jpg: 384x640 1 spur gear, 20 teeths, 14.2ms
# Speed: 4.4ms preprocess, 14.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 13.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\14.jpg: 384x640 1 spur gear, 20 teeths, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 14.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\15.jpg: 384x640 1 spur gear, 20 teeths, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 15.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\16.jpg: 384x640 1 spur gear, 20 teeths, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 16.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\17.jpg: 384x640 1 spur gear, 20 teeths, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 17.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\18.jpg: 384x640 1 spur gear, 20 teeths, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 18.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\19.jpg: 384x640 1 spur gear, 20 teeths, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 19.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\2.jpg: 384x640 1 spur gear, 20 teeths, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 2.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\20.jpg: 384x640 1 spur gear, 20 teeths, 10.4ms
# Speed: 4.1ms preprocess, 10.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 20.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\21.jpg: 384x640 1 spur gear, 20 teeths, 14.2ms
# Speed: 7.0ms preprocess, 14.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 21.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\22.jpg: 384x640 1 spur gear, 20 teeths, 9.5ms
# Speed: 1.8ms preprocess, 9.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 22.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\23.jpg: 384x640 1 spur gear, 20 teeths, 7.8ms
# Speed: 1.8ms preprocess, 7.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 23.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\24.jpg: 384x640 1 spur gear, 20 teeths, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 24.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\25.jpg: 384x640 1 spur gear, 20 teeths, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 25.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\26.jpg: 384x640 1 spur gear, 20 teeths, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 26.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\27.jpg: 384x640 1 spur gear, 20 teeths, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 27.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\28.jpg: 384x640 1 spur gear, 20 teeths, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 28.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\29.jpg: 384x640 1 spur gear, 20 teeths, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 29.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\3.jpg: 384x640 1 spur gear, 20 teeths, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 3.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\30.jpg: 384x640 1 spur gear, 20 teeths, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 30.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\31.jpg: 384x640 1 spur gear, 20 teeths, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 31.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\32.jpg: 384x640 1 spur gear, 20 teeths, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 32.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\33.jpg: 384x640 1 spur gear, 20 teeths, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 33.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\34.jpg: 384x640 1 spur gear, 20 teeths, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 34.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\35.jpg: 384x640 1 spur gear, 20 teeths, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 35.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\36.jpg: 384x640 1 spur gear, 20 teeths, 8.6ms
# Speed: 1.9ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 36.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\37.jpg: 384x640 1 spur gear, 20 teeths, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 37.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\38.jpg: 384x640 1 spur gear, 20 teeths, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 38.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\39.jpg: 384x640 1 spur gear, 20 teeths, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 39.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\4.jpg: 384x640 1 spur gear, 20 teeths, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 4.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\40.jpg: 384x640 1 spur gear, 20 teeths, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 40.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\41.jpg: 384x640 1 spur gear, 20 teeths, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 41.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\42.jpg: 384x640 1 spur gear, 20 teeths, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 42.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\43.jpg: 384x640 1 spur gear, 20 teeths, 10.2ms
# Speed: 4.3ms preprocess, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 43.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\44.jpg: 384x640 1 spur gear, 20 teeths, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 44.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\45.jpg: 384x640 1 spur gear, 20 teeths, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 45.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\46.jpg: 384x640 1 spur gear, 20 teeths, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 46.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\47.jpg: 384x640 1 spur gear, 20 teeths, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 47.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\48.jpg: 384x640 1 spur gear, 20 teeths, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 48.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\49.jpg: 384x640 1 spur gear, 20 teeths, 8.3ms
# Speed: 2.0ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 49.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\5.jpg: 384x640 1 spur gear, 20 teeths, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 5.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\50.jpg: 384x640 1 spur gear, 20 teeths, 8.7ms
# Speed: 2.7ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 50.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\51.jpg: 384x640 1 spur gear, 20 teeths, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 51.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\52.jpg: 384x640 1 spur gear, 20 teeths, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 52.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\53.jpg: 384x640 1 spur gear, 20 teeths, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 53.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\54.jpg: 384x640 1 spur gear, 20 teeths, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 54.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\55.jpg: 384x640 1 spur gear, 20 teeths, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 55.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\56.jpg: 384x640 1 spur gear, 20 teeths, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 56.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\57.jpg: 384x640 1 spur gear, 20 teeths, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 57.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\58.jpg: 384x640 1 spur gear, 20 teeths, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 58.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\59.jpg: 384x640 1 spur gear, 20 teeths, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 59.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\6.jpg: 384x640 1 spur gear, 20 teeths, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 6.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\60.jpg: 384x640 1 spur gear, 20 teeths, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 60.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\61.jpg: 384x640 1 spur gear, 20 teeths, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 61.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\7.jpg: 384x640 1 spur gear, 20 teeths, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 7.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\8.jpg: 384x640 1 spur gear, 20 teeths, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 8.jpg: Defective teeth count (21) != expected (18)
#
# image 1/1 D:\ai\subhi\undistorted gear images\9.jpg: 384x640 1 spur gear, 20 teeths, 22.3ms
# Speed: 2.5ms preprocess, 22.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# ❌ 9.jpg: Defective teeth count (21) != expected (18)
# ⚠️ No non-defective images found after Model 1 detection.

# %%
print("=== Running Model 2: Circle Detection & Diameter Measurement ===")
for fname in os.listdir(model1_output_folder):
    if not fname.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    img_path = os.path.join(model1_output_folder, fname)
    img = cv2.imread(img_path)
    if img is None:
        print(f"⚠️ Cannot read image {fname}, skipping.")
        continue

    results = model2(img_path)[0]

    found_circle = False
    annotated_img = img.copy()

    if results.boxes and results.boxes.xyxy is not None and len(results.boxes.xyxy) > 0:
        for box in results.boxes.xyxy.cpu().numpy():
            x1, y1, x2, y2 = map(int, box)
            cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
            radius = min((x2 - x1), (y2 - y1)) // 2
            diameter_px = radius * 2

            raw_diameter_mm = diameter_px * PIXEL_TO_MM
            corrected_diameter_mm = raw_diameter_mm + ERROR_CORRECTION_MM

            if abs(corrected_diameter_mm - EXPECTED_DIAMETER_MM) <= TOLERANCE_MM:
                status = "✅ OK"
                color = (0, 255, 0)
            else:
                status = "❌ DEFECTIVE"
                color = (0, 0, 255)

            cv2.rectangle(annotated_img, (x1, y1), (x2, y2), color, 2)
            cv2.circle(annotated_img, (cx, cy), radius, color, 2)
            cv2.putText(annotated_img, status, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

            diameter_log.append(
                f"{fname}: Center=({cx},{cy}), Radius={radius}px, "
                f"Diameter={diameter_px}px, Raw={raw_diameter_mm:.2f}mm, "
                f"Corrected={corrected_diameter_mm:.2f}mm, Status={status}"
            )

            found_circle = True
            break  # Assuming only one main circle to detect
    else:
        print(f"⚠️ No circle detected in {fname}")

    annotated_path = os.path.join(model2_annotated_folder, fname)
    saved_annotated = cv2.imwrite(annotated_path, annotated_img)
    if not saved_annotated:
        print(f"⚠️ Failed to save annotated image {annotated_path}")

    if found_circle:
        saved_circle = cv2.imwrite(os.path.join(model2_circle_folder, fname), annotated_img)
        if not saved_circle:
            print(f"⚠️ Failed to save circle image for {fname}")

with open(log_path, "w") as f:
    f.write("\n".join(diameter_log))

print(f"\n✅ Pipeline finished.\n- Non-defective teeth images: {model1_output_folder}\n- Annotated circle images: {model2_annotated_folder}\n- Circle images: {model2_circle_folder}\n- Diameter log saved at: {log_path}")
# Out:
# === Running Model 2: Circle Detection & Diameter Measurement ===
#
# ✅ Pipeline finished.
# - Non-defective teeth images: D:\ai\subhi\predictions\model1_non_defective
# - Annotated circle images: D:\ai\subhi\predictions\model2_annotated
# - Circle images: D:\ai\subhi\predictions\model2_annotated\circles
# - Diameter log saved at: D:\ai\subhi\predictions\diameter_log.txt
